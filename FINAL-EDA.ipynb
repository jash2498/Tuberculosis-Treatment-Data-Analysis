# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df=pd.read_csv('data1.csv')
df
# Out:
#        id  age  sex  bmi  education  cavitation  ttd  failure  alcohol  \
# 0     873   33    0    1          3           1    4        0        1
# 1     190   47    0    2          2           0    6        0        1
# 2    1080   42    1    2          3           0    3        0        0
# 3    1545   29    1    1          0           1    6        0        1
# 4     677   18    0    0          0           1    6        0        1
# ..    ...  ...  ...  ...        ...         ...  ...      ...      ...
# 619  1169   27    0    1          3           0    6        0        0
# 620  1211   26    1    2          0           1    7        0        1
# 621  1212   53    1    2          2           1    0        0        1
# 622   185   60    1    1          3           0    6        0        0
# 623   612   27    0    2          0           0    9        0        0
#
#      mental_health  smoking
# 0                1        1
# 1                1        0
# ...

# %% [markdown]
# ## PANDAS PROFILING

# %%
'''
from pandas_profiling import ProfileReport
prof=ProfileReport(df)
prof.to_file(output_file='output.html')
'''
# Out:
# "\nfrom pandas_profiling import ProfileReport\nprof=ProfileReport(df)\nprof.to_file(output_file='output.html')\n"

# %% [markdown]
# ## Target variable- FAILURE

# %%
failure_counts = df['failure'].value_counts()

# Create a pie chart using Seaborn
plt.figure(figsize=(6, 6))  # Set the size of the plot
sns.set_palette("Set3")     # Set the color palette
plt.pie(failure_counts, labels=failure_counts.index, autopct='%1.1f%%', startangle=180)
# Out:
# ([<matplotlib.patches.Wedge at 0x2726b965700>,
# ...
#  [Text(1.0162674857624152, -0.42095177560159946, '0'),
#   Text(-1.0162674857624152, 0.4209517756015996, '1')],
#  [Text(0.5543277195067718, -0.2296100594190542, '87.5%'),
#   Text(-0.5543277195067718, 0.2296100594190543, '12.5%')])

# %%
df.columns
# Out:
# Index(['id', 'age', 'sex', 'bmi', 'education', 'cavitation', 'ttd', 'failure',
#        'alcohol', 'mental_health', 'smoking'],
#       dtype='object')

# %%
sns.countplot(df['failure'])
# Out:
# C:\Users\Jash\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='failure', ylabel='count'>

# %%
plt.hist(df['age'])
# Out:
# (array([135.,  43.,  64.,  60.,  61.,  82.,  53.,  36.,  35.,  55.]),
#  array([18. , 22.2, 26.4, 30.6, 34.8, 39. , 43.2, 47.4, 51.6, 55.8, 60. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df['age'], color='darkblue')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %% [markdown]
# ## -the distribution of age is positively skewed
# ## - the curve represents the most common age range between 18-22

# %% [markdown]
# ## AGE and FAILURE

# %%
sns.barplot(df['failure'], df['age'])
# Out:
# C:\Users\Jash\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='failure', ylabel='age'>

# %% [markdown]
# ## from the above barplot, we can observe that average age of the failure cases is around 36, average age of success cases is around 38

# %%
sns.barplot(df['failure'], df['age'], hue=df['sex'])
# Out:
# C:\Users\Jash\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='failure', ylabel='age'>

# %% [markdown]
# ##  failure cases- 1.average female age-34
# ##                          2.average male age-37
# ##  succes cases-1.average female age-37
# ##                          2. average male age-38

# %% [markdown]
# ## AGE and SMOKING

# %%
sns.barplot(df['smoking'], df['age'])
# Out:
# C:\Users\Jash\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='smoking', ylabel='age'>

# %% [markdown]
# ## from the above barplot we can observe that the average age of both the smokers and non-smokers is around 36-37.

# %%
sns.barplot(df['smoking'], df['age'], hue=df['sex'])
# Out:
# C:\Users\Jash\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='smoking', ylabel='age'>

# %% [markdown]
# ## among the non smokers the average of both the male and female is around 36
# ## among the smokers the average age of feamale is 34 and average age of male is 37

# %%
sns.countplot(df['smoking'], hue=df['sex'])
# Out:
# C:\Users\Jash\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='smoking', ylabel='count'>

# %% [markdown]
# ## As we can see from the above countplot  that males tend to smoke at slightly higher rates than females.

# %% [markdown]
# ## FAILURE and SMOKING

# %%
sns.countplot(df['failure'], hue=df['smoking'])
# Out:
# C:\Users\Jash\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='failure', ylabel='count'>

# %% [markdown]
# ## There is higher likelihood of smoking in the  failure cases

# %%
import seaborn as sns
import matplotlib.pyplot as plt


crosstab = pd.crosstab(df['failure'], df['smoking'])

plt.figure(figsize=(8, 6))
sns.heatmap(crosstab, annot=True, cmap="YlGnBu", fmt='d')
plt.title('Correlation between Failure and Smoking')
plt.xlabel('Smoking')
plt.ylabel('Failure')

plt.show()

# %% [markdown]
# ## from above heatmap we can observe clearly that there is a noticeable and statistically significant positive correlation between the 'failure' variable and 'smoking' behavior, suggesting that a higher incidence of failure is associated with a higher likelihood of smoking.

# %% [markdown]
# ## AGE and ALCOHOL

# %%
sns.barplot(df['alcohol'], df['age'])
# Out:
# C:\Users\Jash\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='alcohol', ylabel='age'>

# %% [markdown]
# ## From the given data we can observe the average age of abstainers(dont consume alcohol) is 34 and the average age of alcoholic consumers is around 36

# %%
sns.barplot(df['alcohol'], df['age'], hue=df['sex'])
# Out:
# C:\Users\Jash\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='alcohol', ylabel='age'>

# %% [markdown]
# ## among the abstainers-1. average female age-34, 2. average male age-35
#
# ## among alcohol consumers - 1. average female age-34, 2. average male age-37

# %% [markdown]
# ## FAILURE and ALCOHOL

# %%
sns.countplot(df['failure'], hue=df['alcohol'])
# Out:
# C:\Users\Jash\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='failure', ylabel='count'>

# %% [markdown]
# ## There is higher likelihood  of alcohol consumers in the failure cases

# %%
crosstab = pd.crosstab(df['failure'], df['alcohol'])

plt.figure(figsize=(8, 6))
sns.heatmap(crosstab, annot=True, cmap="YlGnBu", fmt='d')
plt.title('Correlation between Failure and Smoking')
plt.xlabel('alcohol consumers')
plt.ylabel('Failure')

plt.show()

# %% [markdown]
# ## There is a noticeable and statistically significant positive correlation between the 'failure' variable and 'alcohol consumption' behavior, suggesting that a higher incidence of failure is associated with a higher likelihood of alcohol consumption

# %% [markdown]
# ## EDUCATION and GENDER

# %%
sns.countplot(df['education'], hue=df['sex'])
# Out:
# C:\Users\Jash\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='education', ylabel='count'>

# %% [markdown]
# ## EDUCATION and MENTAL HEALTH

# %%
sns.countplot(df['education'], hue=df['mental_health'])
# Out:
# C:\Users\Jash\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='education', ylabel='count'>

# %% [markdown]
# ## EDUCATION and ALCOHOL

# %%
sns.countplot(df['education'], hue=df['alcohol'])
# Out:
# C:\Users\Jash\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='education', ylabel='count'>

# %%
crosstab = pd.crosstab(df['education'], df['alcohol'])

plt.figure(figsize=(8, 6))
sns.heatmap(crosstab, annot=True, cmap="YlGnBu", fmt='d')
plt.title('Correlation between education and alcohol consumers')
plt.xlabel('alcohol consumers')
plt.ylabel('education')

plt.show()

# %% [markdown]
# ## EDUCATION and SMOKING

# %%
sns.countplot(df['education'], hue=df['smoking'])
# Out:
# C:\Users\Jash\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='education', ylabel='count'>

# %%
crosstab = pd.crosstab(df['education'], df['smoking'])

plt.figure(figsize=(8, 6))
sns.heatmap(crosstab, annot=True, cmap="YlGnBu", fmt='d')
plt.title('Correlation between education and Smoking')
plt.xlabel('smoking')
plt.ylabel('education')

plt.show()

# %% [markdown]
# ## AGE and BMI

# %%
sns.barplot(df['bmi'], df['age'])
# Out:
# C:\Users\Jash\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bmi', ylabel='age'>

# %%
sns.barplot(df['bmi'], df['age'], hue=df['sex'])
# Out:
# C:\Users\Jash\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bmi', ylabel='age'>

# %% [markdown]
# ## FAILURE and BMI

# %%
sns.countplot(df['failure'], hue=df['bmi'])
# Out:
# C:\Users\Jash\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='failure', ylabel='count'>

# %%
crosstab = pd.crosstab(df['failure'], df['bmi'])

plt.figure(figsize=(8, 6))
sns.heatmap(crosstab, annot=True, cmap="YlGnBu", fmt='d')
plt.title('Correlation between failure and bmi')
plt.xlabel('bmi')
plt.ylabel('failure')

plt.show()

# %% [markdown]
# ## FAILURE and MENTAL HEALTH

# %%
sns.countplot(df['failure'], hue=df['mental_health'])
# Out:
# C:\Users\Jash\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='failure', ylabel='count'>

# %%
crosstab = pd.crosstab(df['failure'], df['mental_health'])

plt.figure(figsize=(8, 6))
sns.heatmap(crosstab, annot=True, cmap="YlGnBu", fmt='d')
plt.title('Correlation between failure and bmi')
plt.xlabel('mental_health')
plt.ylabel('failure')

plt.show()

# %% [markdown]
# ## MENTAL HEALTH and SMOKING , ALCOHOL
